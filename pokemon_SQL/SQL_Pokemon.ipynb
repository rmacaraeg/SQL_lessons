# %% [markdown]
# # groupby and finding the right category/bins/places to slice them in groupbys

# %%
import pandas as pd
import sqlite3
cnx = sqlite3.connect(':memory:')

# %%
csvfile = ('/Users/randy/Documents/GitHub/Pokemon-Stat-Predictor/Pokemon.csv') #Original data

# %%
columns = ['#','name','type1','type2','total','hp','attack','defense',\
           'sp_atk','sp_def','speed','generation','legendary']
#open the csv file
df = pd.read_csv(csvfile, names=columns, header=0)

# %%
#find NaN values
nan_rows = df[df.isnull().T.any().T]
nan_rows.head()
# Out:
#     #        name  type1 type2  total  hp  attack  defense  sp_atk  sp_def  \
# 4   4  Charmander   Fire   NaN    309  39      52       43      60      50
# 5   5  Charmeleon   Fire   NaN    405  58      64       58      80      65
# 9   7    Squirtle  Water   NaN    314  44      48       65      50      64
# 10  8   Wartortle  Water   NaN    405  59      63       80      65      80
# 11  9   Blastoise  Water   NaN    530  79      83      100      85     105
#
#     speed  generation  legendary
# 4      65           1      False
# 5      80           1      False
# 9      43           1      False
# 10     58           1      False
# 11     78           1      False

# %%
#change all Type 2 NaN values to 'None':
df['type2'] = df['type2'].fillna('none')

# %%
#check for NaN values again
nan_rows = df[df.isnull().T.any().T]
nan_rows.head()
# Out:
# Empty DataFrame
# Columns: [#, name, type1, type2, total, hp, attack, defense, sp_atk, sp_def, speed, generation, legendary]
# Index: []

# %%
#change all strings within the dataframe to lower case
df = df.astype(str).apply(lambda x: x.str.lower())

# %%
df.head()
# Out:
#    #                   name  type1   type2 total  hp attack defense sp_atk  \
# 0  1              bulbasaur  grass  poison   318  45     49      49     65
# 1  2                ivysaur  grass  poison   405  60     62      63     80
# 2  3               venusaur  grass  poison   525  80     82      83    100
# 3  3  venusaurmega venusaur  grass  poison   625  80    100     123    122
# 4  4             charmander   fire    none   309  39     52      43     60
#
#   sp_def speed generation legendary
# 0     65    45          1     false
# 1     80    60          1     false
# 2    100    80          1     false
# 3    120    80          1     false
# 4     50    65          1     false

# %%
#set the database for pokemon
df.to_sql('pokemon', con=cnx, if_exists='append', index=False)

# %%
#function for the SQL queries below
def sql_query(query):
    return pd.read_sql(query, cnx)

# %% [markdown]
# # Some Group By examples

# %%
#simple MAX
query = '''
SELECT name, type1, type2, MAX(total)
FROM pokemon
WHERE legendary = 'true';
'''

sql_query(query)
# Out:
#                   name    type1     type2 MAX(total)
# 0  mewtwomega mewtwo x  psychic  fighting        780

# %%
#MAX GROUP BY type1
query = '''
SELECT name, type1, type2, MAX(total)
FROM pokemon
WHERE legendary = 'true'
GROUP BY type1;
'''

sql_query(query)
# Out:
#                        name     type1     type2 MAX(total)
# 0                   yveltal      dark    flying        680
# 1     rayquazamega rayquaza    dragon    flying        780
# 2                    zapdos  electric    flying        580
# 3                   xerneas     fairy      none        680
# 4                     ho-oh      fire    flying        680
# 5   tornadusincarnate forme    flying      none        580
# 6     giratinaaltered forme     ghost    dragon        680
# 7         shayminland forme     grass      none        600
# 8     groudonprimal groudon    ground      fire        770
# 9                  articuno       ice    flying        580
# 10                   arceus    normal      none        720
# 11      mewtwomega mewtwo x   psychic  fighting        780
# 12      dianciemega diancie      rock     fairy        700
# 13                   dialga     steel    dragon        680
# 14      kyogreprimal kyogre     water      none        770

# %% [markdown]
# # HAVING Clause

# %%
#total HP group by type1, SUM(HP) > 4000

query = '''
SELECT COUNT(name) as pokemon_count, type1, MIN(total), MAX(total), AVG(HP)
FROM pokemon
GROUP BY type1
HAVING SUM(HP) > 4000;
'''

sql_query(query)
# Out:
#    pokemon_count    type1 MIN(total) MAX(total)    AVG(HP)
# 0             70    grass        180        630  67.271429
# 1             98   normal        190        720  77.275510
# 2             57  psychic        198        780  70.631579
# 3            112    water        200        770  72.062500

# %% [markdown]
# # Subqueries in the SELECT, FROM, WHERE statements

# %% [markdown]
# # GROUP BY should only be used with the aggregate functions (COUNT, SUM, MAX, MIN, AVG)

# %%
query = '''
SELECT type1, type2, MIN(total), MAX(total)
FROM pokemon
GROUP BY type1, type2;
'''

sql_query(query)
# Out:
#         type1     type2 MIN(total) MAX(total)
# 0         bug  electric        319        472
# 1         bug  fighting        500        600
# 2         bug      fire        360        550
# 3         bug    flying        244        600
# 4         bug     ghost        236        236
# 5         bug     grass        285        500
# 6         bug    ground        266        424
# 7         bug      none        194        500
# 8         bug    poison        195        495
# 9         bug      rock        325        505
# 10        bug     steel        424        600
# 11        bug     water        269        269
# 12       dark    dragon        300        600
# 13       dark  fighting        348        488
# 14       dark      fire        330        600
# 15       dark    flying        370        680
# 16       dark     ghost        380        480
# 17       dark       ice        430        510
# 18       dark      none        220        600
# 19       dark   psychic        288        482
# 20       dark     steel        340        490
# 21     dragon  electric        680        680
# 22     dragon     fairy        590        590
# 23     dragon      fire        680        680
# 24     dragon    flying        490        780
# 25     dragon    ground        300        700
# 26     dragon       ice        660        700
# 27     dragon      none        300        600
# 28     dragon   psychic        600        700
# 29   electric    dragon        610        610
# ..        ...       ...        ...        ...
# 124      rock    ground        300        495
# 125      rock       ice        362        521
# 126      rock      none        280        580
# 127      rock   psychic        440        440
# 128      rock     steel        350        525
# 129      rock     water        306        500
# 130     steel    dragon        680        680
# 131     steel     fairy        380        480
# 132     steel  fighting        580        580
# 133     steel    flying        465        465
# 134     steel     ghost        325        520
# 135     steel    ground        510        610
# 136     steel      none        300        630
# 137     steel   psychic        300        700
# 138     steel      rock        330        530
# 139     water      dark        305        640
# 140     water    dragon        540        680
# 141     water  electric        330        460
# 142     water     fairy        250        420
# 143     water  fighting        510        580
# 144     water    flying        270        540
# 145     water     ghost        335        480
# 146     water     grass        220        480
# 147     water    ground        210        635
# 148     water       ice        475        535
# 149     water      none        200        770
# 150     water    poison        335        515
# 151     water   psychic        315        590
# 152     water      rock        355        495
# 153     water     steel        530        530
#
# [154 rows x 4 columns]

# %%
query = '''
SELECT type1, COUNT(total), SUM(total), MIN(total), MAX(total)
FROM pokemon
WHERE total > 100
GROUP BY type1;
'''

sql_query(query)
# Out:
#        type1  COUNT(total)  SUM(total) MIN(total) MAX(total)
# 0        bug            69       26146        194        600
# 1       dark            31       13818        220        680
# 2     dragon            32       17617        300        780
# 3   electric            44       19510        205        610
# 4      fairy            17        7024        218        680
# 5   fighting            27       11244        210        625
# 6       fire            52       23820        250        680
# 7     flying             4        1940        245        580
# 8      ghost            32       14066        275        680
# 9      grass            70       29480        180        630
# 10    ground            32       14000        265        770
# 11       ice            24       10403        250        580
# 12    normal            98       39365        190        720
# 13    poison            28       11176        245        535
# 14   psychic            57       27129        198        780
# 15      rock            44       19965        280        700
# 16     steel            27       13168        300        700
# 17     water           112       48211        200        770

# %%
df.head()
# Out:
#    #                   name  type1   type2 total  hp attack defense sp_atk  \
# 0  1              bulbasaur  grass  poison   318  45     49      49     65
# 1  2                ivysaur  grass  poison   405  60     62      63     80
# 2  3               venusaur  grass  poison   525  80     82      83    100
# 3  3  venusaurmega venusaur  grass  poison   625  80    100     123    122
# 4  4             charmander   fire    none   309  39     52      43     60
#
#   sp_def speed generation legendary
# 0     65    45          1     false
# 1     80    60          1     false
# 2    100    80          1     false
# 3    120    80          1     false
# 4     50    65          1     false
